# %% [markdown]
# # Data Engineer Interview Questions - Python Basics (3-5 Years Experience)
#
# ## Question 1: Type Casting in Data Pipeline
# **Question:** In a data pipeline, you receive a CSV file where ages are stored as strings. You need to convert them to integers for calculations, but some rows may have invalid data. Write a solution that safely converts the data and handles errors.
#
# ```
# Sample data: ["25", "30", "invalid", "35", ""]
# Expected output: Successfully converted values and logged errors
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 2: Loop Optimization in Data Processing
# **Question:** You have a list of 1 million transactions. Write an optimized loop that filters valid transactions (amount > 0) and calculates total. Compare the efficiency with a list comprehension approach.
#
# ```
# data = [100, -50, 200, 0, 150, -30, 300]
# Expected: Sum of valid transactions and iteration count
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 3: Exception Handling in ETL Pipeline
# **Question:** Design an ETL function that reads data from multiple files. Handle FileNotFoundError, ValueError, and ZeroDivisionError gracefully. Log errors and continue processing.
#
# ```
# Files: data1.csv, data2.csv, data3.csv
# Handle missing files and invalid numeric values
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 4: Variable Scoping in Data Transformations
# **Question:** Explain the difference between local and global scope. Write a function that modifies a global counter variable. Why might this be problematic in parallel data processing?

# %%
# Write your solution here

# %% [markdown]
# ## Question 5: Conditional Logic for Data Validation
# **Question:** Write a validation function for a user record. Check if age is between 18-100, email contains @, and salary is positive. Return specific error messages for each validation failure.
#
# ```
# user_data = {"name": "John", "age": 25, "email": "john@example.com", "salary": 50000}
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 6: Arithmetic Operations for Metrics Calculation
# **Question:** Calculate average salary, median salary growth, and salary variance from a list. Handle edge cases like empty lists or negative values.
#
# ```
# salaries = [50000, 60000, 70000, 80000, 90000]
# expected_outputs: mean, median, variance
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 7: String Manipulation in Data Cleaning
# **Question:** Clean and normalize log data. Convert to lowercase, remove leading/trailing spaces, replace special characters with underscores, and split by delimiter.
#
# ```
# logs = ["  ERROR_Event ", "  WARNING_Data ", "SUCCESS_Complete  "]
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 8: Break and Continue in Data Filtering
# **Question:** Write a function that processes a transaction list, skips invalid transactions (amount <= 0) with continue, and stops processing if a fraud flag is found with break. Count valid transactions processed.
#
# ```
# transactions = [100, -50, 200, None, 150, 'FRAUD', 300]
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 9: Boolean Logic in Data Quality Checks
# **Question:** Write a function that validates data quality. Record passes QC if (has_valid_id AND non_null_values) OR (has_backup_source AND approved_flag). Return detailed validation results.
#
# ```
# record1 = {"id": 123, "values": [1,2,3], "backup": None, "approved": False}
# record2 = {"id": None, "values": [], "backup": "source_b", "approved": True}
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 10: File I/O and Data Loading
# **Question:** Write a function that reads a CSV file line by line, parses each line, handles encoding errors, and returns a list of dictionaries. Include error handling for missing files.
#
# ```
# Expected: Read CSV, convert to list of dicts, handle errors gracefully
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 11: Type Conversion in Aggregations
# **Question:** A data warehouse stores numeric values as strings in different formats ("123", "45.67", "1,234.56"). Convert all to float, handle invalid entries, and calculate sum and average.
#
# ```
# values = ["123", "45.67", "invalid", "1,234.56", None]
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 12: Nested Loops with Break - Early Termination
# **Question:** Find the first duplicate value in a nested list of user IDs. Use nested loops with break to exit as soon as duplicate is found. Return position and value.
#
# ```
# user_ids = [[101, 102, 103], [104, 105, 106], [102, 107, 108]]
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 13: String Methods in Data Normalization
# **Question:** Implement a data normalization function that handles various string formats: removes whitespace, standardizes case, removes special characters, and validates output. Use string methods like strip(), replace(), split().
#
# ```
# raw_data = ["  John@Doe! ", "  Jane#Smith? ", "Bob$Johnson "]
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 14: Complex Exception Handling Chain
# **Question:** Write a robust data ingestion function. Handle FileNotFoundError (retry once), ValueError (log and skip), ZeroDivisionError (use default), and generic Exception (alert). Return summary stats.
#
# ```
# Simulate reading from multiple files with different error scenarios
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 15: Scope Management in Recursive Functions
# **Question:** Write a recursive function to parse nested data structures (tree). Explain variable scope at each recursion level. Show how to properly handle mutable default arguments in function signatures.
#
# ```
# data = {"user": "John", "nested": {"level": 2, "nested": {"level": 3}}}
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 16: Input/Output Operations in Batch Processing
# **Question:** Build a batch processor that reads data from multiple files, validates each record, writes valid records to output file, and logs errors to error file. Use context managers.
#
# ```
# Input files: batch1.txt, batch2.txt, batch3.txt
# Output: valid_records.txt, error_log.txt
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 17: Conditional Logic with Multiple Branches
# **Question:** Implement a data quality score calculator. Given a record, apply weighted conditions: valid_id (20%), non_null_fields (30%), valid_types (25%), no_duplicates (25%). Return score and grade (A/B/C/D/F).
#
# ```
# record = {"id": 123, "name": "John", "age": 25, "email": "john@test.com"}
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 18: Loop with Enumerate and Indexing
# **Question:** Process a list of database records. For each record, check if current value exceeds previous value. Use enumerate and indexing. Track increasing/decreasing trends. Skip null values.
#
# ```
# values = [100, 150, 120, 200, None, 180, 210, 195]
# Expected: Identify all trend changes
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 19: Combined Operators - Practical Data Pipeline
# **Question:** Write a data pipeline function combining: type casting (str to int), arithmetic operations (percentage calculations), conditional checks (thresholds), and loop control (skip/process). Process payroll data with min salary validation.
#
# ```
# employees = [("John", "50000"), ("Jane", "60000"), ("Bob", "-5000"), ("Alice", "invalid")]
# min_salary = 40000, target_increase = 10%
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Question 20: Production-Ready Data Validation System
# **Question:** Create a complete validation system for incoming data. Combine all concepts: type checking/conversion, exception handling, conditional validation, loop processing, logical operators, and file I/O. Return detailed quality report.
#
# ```
# Design a system that:
# 1. Reads raw data from file
# 2. Validates each field with specific rules
# 3. Converts types safely
# 4. Handles errors gracefully
# 5. Generates detailed report
# 6. Logs all errors
# ```

# %%
# Write your solution here
